# %% [markdown]
# # 여러가지 방법으로 데이터 학습시키기

# %% [markdown]
# ## case 1. sm7_result_1
#  - custom한 mask데이터 학습하기
#  - img : 640, batch : 16, epoch : 3
#  - 2022.03.28
#
#
#  - 결과
#      - nomask 인식 불가
#      - 웹캠에서 확인 시에도 얼굴 전체를 디텍팅하지 못함

# %% [markdown]
# ## case 2. sm7_result_2
#  - custom한 mask데이터 학습하기
#  - img : 1,280, batch : 16, epoch : 200
#  - 2022.03.29 현재 학습 중

# %% [markdown]
# ## case 3. sm7_result
#  - custom한 mask데이터에 roboflow에서 다운받은 mask데이터 합쳐서 학습하기
#  - img : 640, batch : 16, epoch : 5
#  - 2022.03.29
#
#  - 결과
#      - nomask 인식 O
#      - 웹캠에서 확인 시 nomask 인식 불가, 얼굴 디텍팅은 가능

# %% [markdown]
# ## case 4. sm7_result_2
#  - custom한 mask데이터에 roboflow에서 다운받은 mask데이터 합쳐서 학습하기
#  - img : 640, batch : 16, epoch : 20
#  - 2022.03.29

# %%
# !python /home/tutor/yolov5/train.py --img 640 --batch 16 --epochs 20 --data /home/tutor/yolov5/data/sm7.yaml --cfg /home/tutor/yolov5/models/yolov5s.yaml --weights /home/tutor/yolov5/yolov5s.pt --name sm7_result
# Out:
# train: weights=/home/tutor/yolov5/yolov5s.pt, cfg=/home/tutor/yolov5/models/yolov5s.yaml, data=/home/tutor/yolov5/data/sm7.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=sm7_result, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-73-gd51f9b2 torch 1.11.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %% [markdown]
# ## case 5. sm7_result_3
#  - custom한 mask데이터에 roboflow에서 다운받은 mask데이터 합쳐서 학습하기
#  - img : 640, batch : 16, epoch : 3
#  - 2022.03.29

# %%
# !python /home/tutor/yolov5/train.py --img 640 --batch 16 --epochs 3 --data /home/tutor/yolov5/data/sm7.yaml --cfg /home/tutor/yolov5/models/yolov5s.yaml --weights /home/tutor/yolov5/yolov5s.pt --name sm7_result
# Out:
# train: weights=/home/tutor/yolov5/yolov5s.pt, cfg=/home/tutor/yolov5/models/yolov5s.yaml, data=/home/tutor/yolov5/data/sm7.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=sm7_result, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-73-gd51f9b2 torch 1.11.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %% [markdown]
# ## case 6. sm7_result_4
#  - custom한 mask데이터에 roboflow에서 다운받은 mask데이터 합쳐서 학습하기
#  - img : 1280, batch : 16, epoch : 5
#  - 2022.03.29

# %%
# !python /home/tutor/yolov5/train.py --img 1280 --batch 16 --epochs 5 --data /home/tutor/yolov5/data/sm7.yaml --cfg /home/tutor/yolov5/models/yolov5s.yaml --weights /home/tutor/yolov5/yolov5s.pt --name sm7_result
# Out:
# train: weights=/home/tutor/yolov5/yolov5s.pt, cfg=/home/tutor/yolov5/models/yolov5s.yaml, data=/home/tutor/yolov5/data/sm7.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=5, batch_size=16, imgsz=1280, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=sm7_result, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-73-gd51f9b2 torch 1.11.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %% [markdown]
# ## case 7. sm7_custom_result
#  - custom한 mask데이터 학습하기
#  - img : 640, batch : 16, epoch : 20
#  - 2022.03.29

# %%
# !python /home/tutor/yolov5/train.py --img 640 --batch 16 --epochs 20 --data /home/tutor/yolov5/data/sm7.yaml --cfg /home/tutor/yolov5/models/yolov5s.yaml --weights /home/tutor/yolov5/yolov5s.pt --name sm7_custom_result
# Out:
# train: weights=/home/tutor/yolov5/yolov5s.pt, cfg=/home/tutor/yolov5/models/yolov5s.yaml, data=/home/tutor/yolov5/data/sm7.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=sm7_custom_result, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-73-gd51f9b2 torch 1.11.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %% [markdown]
# ## case 8. sm7_result_5
#  - custom한 mask데이터 + roboflow 학습하기
#  - img : 640, batch : 16, epoch : 200
#  - 2022.03.29-2022.03.30

# %%
# !python /home/tutor/yolov5/train.py --img 640 --batch 16 --epochs 200 --data /home/tutor/yolov5/data/sm7_roboflow.yaml --cfg /home/tutor/yolov5/models/yolov5s.yaml --weights /home/tutor/yolov5/yolov5s.pt --name sm7_result

# %% [markdown]
# ## case 9. sm7_result_6
#  - custom한 mask데이터(성배님) + roboflow 학습하기 ++사이즈 640로 변환
#  - img : 640, batch : 64, epoch : 50
#  - 2022.03.30

# %%
# !python /home/tutor/yolov5/train.py --img 640 --batch 64 --epochs 50 --data /home/tutor/yolov5/data/sm7_roboflow_640_SB.yaml --cfg /home/tutor/yolov5/models/yolov5s.yaml --weights /home/tutor/yolov5/yolov5s.pt --name case9
# Out:
# train: weights=/home/tutor/yolov5/yolov5s.pt, cfg=/home/tutor/yolov5/models/yolov5s.yaml, data=/home/tutor/yolov5/data/sm7_roboflow_640_SB.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=64, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=case9, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 1 commit. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-73-gd51f9b2 torch 1.11.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %% [markdown]
# ## case 11. sm7_small_result
#  - custom한 mask데이터(SMALL)
#  - img : 640 , batch : 16, epoch : 20
#  - 2022.03.30

# %%
# !python /home/tutor/yolov5/train.py --img 640 --batch 16 --epochs 20 --data /home/tutor/yolov5/data/sm7_small.yaml --cfg /home/tutor/yolov5/models/yolov5s.yaml --weights /home/tutor/yolov5/yolov5s.pt --name sm7_small_result
# Out:
# train: weights=/home/tutor/yolov5/yolov5s.pt, cfg=/home/tutor/yolov5/models/yolov5s.yaml, data=/home/tutor/yolov5/data/sm7_small.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=sm7_small_result, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 113, done.
# remote: Counting objects: 100% (90/90), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 113 (delta 75), reused 89 (delta 74), pack-reused 23
# Receiving objects: 100% (113/113), 27.85 KiB | 27.85 MiB/s, done.
# ...

# %% [markdown]
# # case 12 sm7_small_result2
# - custom한 mask데이터(SMALL)
# - img : 640 , batch : 64, epoch : 20
# - 2022.03.30

# %%
# !python /home/tutor/yolov5/train.py --img 640 --batch 64 --epochs 20 --data /home/tutor/yolov5/data/sm7_small.yaml --cfg /home/tutor/yolov5/models/yolov5s.yaml --weights /home/tutor/yolov5/yolov5s.pt --name sm7_small_result
# Out:
# train: weights=/home/tutor/yolov5/yolov5s.pt, cfg=/home/tutor/yolov5/models/yolov5s.yaml, data=/home/tutor/yolov5/data/sm7_small.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=64, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=sm7_small_result, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 1 commit. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-73-gd51f9b2 torch 1.11.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %% [markdown]
# # case 13 sm7_small_robo_result
# small + roboflow
# img : 640 , batch : 64, epoch : 20
# 2022.03.30

# %%
# !python /home/tutor/yolov5/train.py --img 640 --batch 64 --epochs 20 --data /home/tutor/yolov5/data/sm7_small_roboflow.yaml --cfg /home/tutor/yolov5/models/yolov5s.yaml --weights /home/tutor/yolov5/yolov5s.pt --name sm7_small_robo_result
# Out:
# train: weights=/home/tutor/yolov5/yolov5s.pt, cfg=/home/tutor/yolov5/models/yolov5s.yaml, data=/home/tutor/yolov5/data/sm7_small_roboflow.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=sm7_small_robo_result, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 1 commit. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-73-gd51f9b2 torch 1.11.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %% [markdown]
# # case 14 sm7_small_robo_result2
# - small + roboflow
# - img : 640 , batch : 16, epoch : 20

# %%
# !python /home/tutor/yolov5/train.py --img 640 --batch 16 --epochs 20 --data /home/tutor/yolov5/data/sm7_small_roboflow.yaml --cfg /home/tutor/yolov5/models/yolov5s.yaml --weights /home/tutor/yolov5/yolov5s.pt --name sm7_small_robo_result
